# %% [markdown]
# Dominik Kwiecień 242448 \
# Hubert Pietras 242494

# %% [markdown]
# # Import od necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read data from dataset

# %%
df = pd.read_csv("data/data.csv", header=None)
df.columns = ['sex', 'length', 'diameter', 'height', 'whole weight', 'shucked weight', 'viscera weight', 'shell weight', 'rings']

# %% [markdown]
# # Assignments for maximum grade 4

# %% [markdown]
# 1. First table

# %%
count = df['sex'].value_counts()
percentage = round(100 * count/df.count()['sex'], 2)

distribution = pd.concat([count, percentage], axis=1, ignore_index=True)
distribution.columns = ['Count', '%']
distribution.index = ['Male', 'Female', 'Infant']

distribution
# Out:
#         Count      %
# Male     1528  36.58
# Female   1342  32.13
# Infant   1307  31.29

# %% [markdown]
# 2. Second table

# %%
summary_statistics = df.describe().T.drop('count', axis='columns')
summary_statistics
# Out:
#                     mean       std     min     25%     50%     75%      max
# length          0.523992  0.120093  0.0750  0.4500  0.5450   0.615   0.8150
# diameter        0.407881  0.099240  0.0550  0.3500  0.4250   0.480   0.6500
# height          0.139516  0.041827  0.0000  0.1150  0.1400   0.165   1.1300
# whole weight    0.828742  0.490389  0.0020  0.4415  0.7995   1.153   2.8255
# shucked weight  0.359367  0.221963  0.0010  0.1860  0.3360   0.502   1.4880
# viscera weight  0.180594  0.109614  0.0005  0.0935  0.1710   0.253   0.7600
# shell weight    0.238831  0.139203  0.0015  0.1300  0.2340   0.329   1.0050
# rings           9.933684  3.224169  1.0000  8.0000  9.0000  11.000  29.0000

# %% [markdown]
# 3. Bar chart of the counts of occurrences of each category for the qualitative variable in the dataset

# %%
fig, ax = plt.subplots()
ax.bar(['Male', 'Female', 'Infant'], df['sex'].value_counts(), width=0.6)
plt.plot();

# %% [markdown]
# 4. Histogram of each quantitative variable in the dataset

# %%
figure, axis = plt.subplots(nrows=4, ncols=2, figsize=(20,35)) 

axis[0, 0].hist(df['length'])
axis[0, 0].set_title('length [mm]')
axis[0, 0].set_ylim(0, 1200)
axis[0, 0].set_xlim(0, 1.0)

axis[0, 1].hist(df['diameter'])
axis[0, 1].set_title('diameter [mm]')
axis[0, 1].set_ylim(0, 1200)
axis[0, 1].set_xlim(0, 0.8)

axis[1, 0].hist(df['height'])
axis[1, 0].set_title('height [mm]')
axis[1, 0].set_ylim(0, 3500)
axis[1, 0].set_xlim(-0.1, 1.0)

axis[1, 1].hist(df['whole weight'])
axis[1, 1].set_title('whole weight [g]')
axis[1, 1].set_ylim(0, 900)
axis[1, 1].set_xlim(-0.1, 3.0)

axis[2, 0].hist(df['shucked weight'])
axis[2, 0].set_title('shucked weight [g]')
axis[2, 0].set_ylim(0, 1200)
axis[2, 0].set_xlim(-0.1, 1.6)

axis[2, 1].hist(df['viscera weight'])
axis[2, 1].set_title('viscera weight [g]')
axis[2, 1].set_ylim(0, 1200)
axis[2, 1].set_xlim(-0.1, 1.0)

axis[3, 0].hist(df['shell weight'])
axis[3, 0].set_title('shell weight [g]')
axis[3, 0].set_ylim(0, 1200)
axis[3, 0].set_xlim(-0.1, 1.0)

axis[3, 1].hist(df['rings'])
axis[3, 1].set_title('rings')
axis[3, 1].set_ylim(0, 1800)
axis[3, 1].set_xlim(0, 30.0)

plt.show()

# %% [markdown]
# 5. Scatter plot for each pair of the quantitative variables in the dataset

# %%
figure, axis = plt.subplots(nrows=14, ncols=2, figsize=(20,100))

axis[0, 0].scatter(df['length'], df['diameter'], s=2)
axis[0, 0].set_title('length(diameter)')
axis[0, 0].set_xlabel('length [mm]')
axis[0, 0].set_ylabel('diameter [mm]')
axis[0, 0].set_xlim(0, 0.9)
axis[0, 0].set_ylim(0, 0.7)

axis[0, 1].scatter(df['length'], df['height'], s=2)
axis[0, 1].set_title('length(height)')
axis[0, 1].set_xlabel('length [mm]')
axis[0, 1].set_ylabel('height [mm]')
axis[0, 1].set_xlim(0, 0.9)
axis[0, 1].set_ylim(-0.1, 1.2)

axis[1, 0].scatter(df['length'], df['whole weight'], s=2)
axis[1, 0].set_title('length(whole weight)')
axis[1, 0].set_xlabel('length [mm]')
axis[1, 0].set_ylabel('shucked weight [g]')
axis[1, 0].set_xlim(0, 0.9)
axis[1, 0].set_ylim(-0.1, 3.0)

axis[1, 1].scatter(df['length'], df['shucked weight'], s=2)
axis[1, 1].set_title('length(shucked weight)')
axis[1, 1].set_xlabel('length [mm]')
axis[1, 1].set_ylabel('shucked weight [g]')
axis[1, 1].set_xlim(0, 0.9)
axis[1, 1].set_ylim(-0.1, 1.6)

axis[2, 0].scatter(df['length'], df['viscera weight'], s=2)
axis[2, 0].set_title('length(viscera weight)')
axis[2, 0].set_xlabel('length [mm]')
axis[2, 0].set_ylabel('viscera weight [g]')
axis[2, 0].set_xlim(0, 0.9)
axis[2, 0].set_ylim(-0.1, 0.8)

axis[2, 1].scatter(df['length'], df['shell weight'], s=2)
axis[2, 1].set_title('length(shell weight)')
axis[2, 1].set_xlabel('length [mm]')
axis[2, 1].set_ylabel('shell weight [g]')
axis[2, 1].set_xlim(0, 0.9)
axis[2, 1].set_ylim(-0.1, 1.2)

axis[3, 0].scatter(df['length'], df['rings'], s=2)
axis[3, 0].set_title('length(rings)')
axis[3, 0].set_xlabel('length [mm]')
axis[3, 0].set_ylabel('rings')
axis[3, 0].set_xlim(0, 0.9)
axis[3, 0].set_ylim(-0.1, 30.0)

axis[3, 1].scatter(df['diameter'], df['height'], s=2)
axis[3, 1].set_title('diameter(height)')
axis[3, 1].set_xlabel('diameter [mm]')
axis[3, 1].set_ylabel('height [mm]')
axis[3, 1].set_xlim(0, 0.7)
axis[3, 1].set_ylim(-0.1, 1.2)

axis[4, 0].scatter(df['diameter'], df['whole weight'], s=2)
axis[4, 0].set_title('diameter(whole weight)')
axis[4, 0].set_xlabel('diameter [mm]')
axis[4, 0].set_ylabel('whole weight [g]')
axis[4, 0].set_xlim(0, 0.7)
axis[4, 0].set_ylim(-0.1, 3.0)

axis[4, 1].scatter(df['diameter'], df['shucked weight'], s=2)
axis[4, 1].set_title('diameter(shucked weight)')
axis[4, 1].set_xlabel('diameter [mm]')
axis[4, 1].set_ylabel('shucked weight [g]')
axis[4, 1].set_xlim(0, 0.7)
axis[4, 1].set_ylim(-0.1, 1.6)

axis[5, 0].scatter(df['diameter'], df['viscera weight'], s=2)
axis[5, 0].set_title('diameter(viscera weight)')
axis[5, 0].set_xlabel('diameter [mm]')
axis[5, 0].set_ylabel('viscera weight [g]')
axis[5, 0].set_xlim(0, 0.7)
axis[5, 0].set_ylim(-0.1, 0.8)

axis[5, 1].scatter(df['diameter'], df['shell weight'], s=2)
axis[5, 1].set_title('diameter(shell weight)')
axis[5, 1].set_xlabel('diameter [mm]')
axis[5, 1].set_ylabel('shell weight [g]')
axis[5, 1].set_xlim(0, 0.7)
axis[5, 1].set_ylim(-0.1, 1.2)

axis[6, 0].scatter(df['diameter'], df['rings'], s=2)
axis[6, 0].set_title('diameter(rings)')
axis[6, 0].set_xlabel('diameter [mm]')
axis[6, 0].set_ylabel('rings')
axis[6, 0].set_xlim(0, 0.7)
axis[6, 0].set_ylim(-0.1, 30.0)

axis[6, 1].scatter(df['height'], df['whole weight'], s=2)
axis[6, 1].set_title('height(whole weight)')
axis[6, 1].set_xlabel('height [mm]')
axis[6, 1].set_ylabel('whole weight [g]')
axis[6, 1].set_xlim(-0.1, 1.2)
axis[6, 1].set_ylim(-0.1, 3.0)

axis[7, 0].scatter(df['height'], df['shucked weight'], s=2)
axis[7, 0].set_title('height(shucked weight)')
axis[7, 0].set_xlabel('height [mm]')
axis[7, 0].set_ylabel('shucked weight [g]')
axis[7, 0].set_xlim(-0.1, 1.2)
axis[7, 0].set_ylim(-0.1, 1.6)

axis[7, 1].scatter(df['height'], df['viscera weight'], s=2)
axis[7, 1].set_title('height(viscera weight)')
axis[7, 1].set_xlabel('height [mm]')
axis[7, 1].set_ylabel('viscera weight [g]')
axis[7, 1].set_xlim(-0.1, 1.2)
axis[7, 1].set_ylim(-0.1, 0.8)

axis[8, 0].scatter(df['height'], df['shell weight'], s=2)
axis[8, 0].set_title('height(shell weight)')
axis[8, 0].set_xlabel('height [mm]')
axis[8, 0].set_ylabel('shell weight [g]')
axis[8, 0].set_xlim(-0.1, 1.2)
axis[8, 0].set_ylim(-0.1, 1.2)

axis[8, 1].scatter(df['height'], df['rings'], s=2)
axis[8, 1].set_title('height(rings)')
axis[8, 1].set_xlabel('height [mm]')
axis[8, 1].set_ylabel('rings')
axis[8, 1].set_xlim(-0.1, 1.2)
axis[8, 1].set_ylim(-0.1, 30.0)

axis[9, 0].scatter(df['whole weight'], df['shucked weight'], s=2)
axis[9, 0].set_title('whole weight(shucked weight)')
axis[9, 0].set_xlabel('whole weight [g]')
axis[9, 0].set_ylabel('shucked weight [g]')
axis[9, 0].set_xlim(-0.1, 3.0)
axis[9, 0].set_ylim(-0.1, 1.6)

axis[9, 1].scatter(df['whole weight'], df['viscera weight'], s=2)
axis[9, 1].set_title('whole weight(viscera weight)')
axis[9, 1].set_xlabel('whole weight [g]')
axis[9, 1].set_ylabel('viscera weight [g]')
axis[9, 1].set_xlim(-0.1, 3.0)
axis[9, 1].set_ylim(-0.1, 0.8)

axis[10, 0].scatter(df['whole weight'], df['shell weight'], s=2)
axis[10, 0].set_title('whole weight(shell weight)')
axis[10, 0].set_xlabel('whole weight [g]')
axis[10, 0].set_ylabel('shell weight [g]')
axis[10, 0].set_xlim(-0.1, 3.0)
axis[10, 0].set_ylim(-0.1, 1.2)

axis[10, 1].scatter(df['whole weight'], df['rings'], s=2)
axis[10, 1].set_title('length(rings)')
axis[10, 1].set_xlabel('whole weight [g]')
axis[10, 1].set_ylabel('rings')
axis[10, 1].set_xlim(-0.1, 3.0)
axis[10, 1].set_ylim(-0.1, 30.0)

axis[11, 0].scatter(df['shucked weight'], df['viscera weight'], s=2)
axis[11, 0].set_title('shucked weight(viscera weight)')
axis[11, 0].set_xlabel('shucked weight [g]')
axis[11, 0].set_ylabel('viscera weight [g]')
axis[11, 0].set_xlim(-0.1, 1.6)
axis[11, 0].set_ylim(-0.1, 0.8)

axis[11, 1].scatter(df['shucked weight'], df['shell weight'], s=2)
axis[11, 1].set_title('shucked weight(shell weight)')
axis[11, 1].set_xlabel('shucked weight [g]')
axis[11, 1].set_ylabel('shell weight [g]')
axis[11, 1].set_xlim(-0.1, 1.6)
axis[11, 1].set_ylim(-0.1, 1.2)

axis[12, 0].scatter(df['shucked weight'], df['rings'], s=2)
axis[12, 0].set_title('shucked weight(rings)')
axis[12, 0].set_xlabel('shucked weight [g]')
axis[12, 0].set_ylabel('rings')
axis[12, 0].set_xlim(-0.1, 1.6)
axis[12, 0].set_ylim(-0.1, 30.0)

axis[12, 1].scatter(df['viscera weight'], df['shell weight'], s=2)
axis[12, 1].set_title('viscera weight(shell weight)')
axis[12, 1].set_xlabel('viscera weight [g]')
axis[12, 1].set_ylabel('shell weight [g]')
axis[12, 1].set_xlim(-0.1, 0.8)
axis[12, 1].set_ylim(-0.1, 1.2)

axis[13, 0].scatter(df['viscera weight'], df['rings'], s=2)
axis[13, 0].set_title('viscera weight(rings)')
axis[13, 0].set_xlabel('viscera weight [g]')
axis[13, 0].set_ylabel('rings')
axis[13, 0].set_xlim(-0.1, 0.8)
axis[13, 0].set_ylim(-0.1, 30.0)

axis[13, 1].scatter(df['shell weight'], df['rings'], s=2)
axis[13, 1].set_title('shell weight(rings)')
axis[13, 1].set_xlabel('shell weight [g]')
axis[13, 1].set_ylabel('rings')
axis[13, 1].set_xlim(-0.1, 1.2)
axis[13, 1].set_ylim(-0.1, 30.0)

plt.show()

# %% [markdown]
# 6. Table representing a linear correlation matrix of all quantitative variables in the dataset

# %%
quantitative_data = df.drop('sex', axis='columns')
quantitative_data.corr()
# Out:
#                   length  diameter    height  whole weight  shucked weight  \
# length          1.000000  0.986812  0.827554      0.925261        0.897914
# diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# height          0.827554  0.833684  1.000000      0.819221        0.774972
# whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 viscera weight  shell weight     rings
# length                0.903018      0.897706  0.556720
# diameter              0.899724      0.905330  0.574660
# height                0.798319      0.817338  0.557467
# whole weight          0.966375      0.955355  0.540390
# ...

# %% [markdown]
# 7. Heatmap representing a linear correlation matrix of all quantitative variables in the dataset

# %%
sns.heatmap(quantitative_data.corr());

# %% [markdown]
# 8. Linear regression plot with the two quantitative variables that are most strongly linearly correlated

# %%
def get_redundant_pairs(df):
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=1):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]
    
top_corr = list(get_top_abs_correlations(quantitative_data).index)
reg_plot = sns.lmplot(x=top_corr[0][0], y=top_corr[0][1], data=df, line_kws={"color": "C1"}, scatter_kws={"s": 2})
reg_plot.set(xlim=(0, 1.0))
reg_plot.set(ylim=(0, 0.7));

# %% [markdown]
# # Assignments for maximum grade of 5

# %% [markdown]
# 2. Table with summary statistics for the quantitative variables in the dataset split by the categories of the qualitative variable

# %%
def summary_stats(x):
    return pd.DataFrame({
        'mean': x.mean(),
        'std': x.std(),
        'min': x.min(),
        '25%': x.quantile(0.25),
        '50%': x.median(),
        '75%': x.quantile(0.75),
        'max': x.max()
    })

def swap_columns(df, col1, col2):
    col_list = list(df.columns)
    x, y = col_list.index(col1), col_list.index(col2)
    col_list[y], col_list[x] = col_list[x], col_list[y]
    df = df[col_list]
    return df

feature_order = ['length', 'diameter', 'height', 'whole weight', 'shucked weight', 'viscera weight', 'shell weight', 'rings']

grouped = df.groupby('sex')
summary_table = grouped[feature_order].apply(summary_stats).reset_index()

summary_table.columns = ['Sex', 'Feature', 'mean', 'std', 'min', '25%', '50%', '75%', 'max']
summary_table = swap_columns(summary_table, 'Sex', 'Feature')

summary_table['Feature'] = pd.Categorical(summary_table['Feature'], feature_order)
summary_table = summary_table.sort_values(['Feature', 'Sex'])

summary_table = summary_table.replace('F', 'Female')
summary_table = summary_table.replace('I', 'Infant')
summary_table = summary_table.replace('M', 'Male')

summary_table = summary_table.set_index(['Feature', 'Sex'])

summary_table
# Out:
#                             mean       std     min       25%       50%  \
# Feature        Sex
# length         Female   0.579093  0.086160  0.2750  0.525000   0.59000
#                Infant   0.427746  0.108858  0.0750  0.360000   0.43500
#                Male     0.561391  0.102697  0.1550  0.505000   0.58000
# diameter       Female   0.454732  0.070954  0.1950  0.410000   0.46500
#                Infant   0.326494  0.088109  0.0550  0.270000   0.33500
#                Male     0.439287  0.084398  0.1100  0.395000   0.45500
# height         Female   0.158011  0.039984  0.0150  0.140000   0.16000
#                Infant   0.107996  0.031995  0.0000  0.085000   0.11000
#                Male     0.151381  0.034804  0.0250  0.130000   0.15500
# whole weight   Female   1.046532  0.430316  0.0800  0.730000   1.03850
#                Infant   0.431363  0.286275  0.0020  0.205500   0.38400
#                Male     0.991459  0.470581  0.0155  0.671625   0.97575
# ...

# %% [markdown]
# 3. Boxplot of each quantitative variable in the dataset, grouping every one of them by the qualitative variable

# %%
data_male = df.loc[df['sex'] == 'M']
data_infant = df.loc[df['sex'] == 'I']
data_female = df.loc[df['sex'] == 'F']

def data_list(x:str):
    return [data_male[x], data_infant[x], data_female[x]]

xticklabels = ['Male', 'Infant', 'Female']

figure, axis = plt.subplots(nrows=4, ncols=2, figsize=(20, 35))

axis[0, 0].boxplot(data_list('length'))
axis[0, 0].set_xticklabels(xticklabels)
axis[0, 0].set_title('length [mm]')
axis[0, 0].set_ylim(-0.1, 1.0)

axis[0, 1].boxplot(data_list('diameter'))
axis[0, 1].set_xticklabels(xticklabels)
axis[0, 1].set_title('diameter [mm]')
axis[0, 1].set_ylim(-0.1, 0.8)

axis[1, 0].boxplot(data_list('height'))
axis[1, 0].set_xticklabels(xticklabels)
axis[1, 0].set_title('height [mm]')
axis[1, 0].set_ylim(-0.1, 1.2)

axis[1, 1].boxplot(data_list('whole weight'))
axis[1, 1].set_xticklabels(xticklabels)
axis[1, 1].set_title('whole weight [g]')
axis[1, 1].set_ylim(-0.1, 3.0)

axis[2, 0].boxplot(data_list('shucked weight'))
axis[2, 0].set_xticklabels(xticklabels)
axis[2, 0].set_title('shucked weight [g]')
axis[2, 0].set_ylim(-0.1, 1.6)

axis[2, 1].boxplot(data_list('viscera weight'))
axis[2, 1].set_xticklabels(xticklabels)
axis[2, 1].set_title('viscera weight [g]')
axis[2, 1].set_ylim(-0.1, 0.9)

axis[3, 0].boxplot(data_list('shell weight'))
axis[3, 0].set_xticklabels(xticklabels)
axis[3, 0].set_title('shell weight [g]')
axis[3, 0].set_ylim(-0.1, 1.2)

axis[3, 1].boxplot(data_list('rings'))
axis[3, 1].set_xticklabels(xticklabels)
axis[3, 1].set_title('rings')
axis[3, 1].set_ylim(-0.1, 30.0)

plt.show()
